# %%
import pandas as pd
import numpy as np
from pathlib import Path
import plotly.express as px
import time

# %%
from sklearn.model_selection import train_test_split, cross_val_predict, TimeSeriesSplit
from sklearn.linear_model import Ridge
from sklearn.feature_selection import SelectKBest, f_regression
import lightgbm as lgb

# %%
from src.metrics import cosine_similarity

# %% [markdown]
# # 環境設定

# %%
DATA_PATH = "./data"
RESULT_PATH = "./results"

# %% [markdown]
# # 関数定義

# %%
# KFoldを実装
# cv splitterは， split関数でインデックスの配列を返す必要があるぽい
class GroupTimeSeriesSplit:
    def __init__(self, n_splits=5):
        self.n_splits = n_splits

    def split(self, X, y, groups=None):
        n = X.shape[0]
        group_samples = 10000
        group_count = (n + group_samples - 1) // group_samples
        groups = np.arange(group_count) # グループ数

        def group_idx_to_idx(idx):
            """group_idxをidxに変換する.
            group_idx_to_idx(1)
            >>> np.array([10000, 19999])
            """
            return np.concatenate([
                np.arange(group_samples * g, min(n, group_samples * (g + 1)))
                for g in idx
            ])

        cv = TimeSeriesSplit(self.n_splits)
        for train_index, test_index in cv.split(groups):
            yield group_idx_to_idx(train_index), group_idx_to_idx(test_index)

    def get_n_splits(self):
        return self.n_splits

# %%
def time_series_cross_val_predict(model, X_train, y_train, cv) -> tuple[np.ndarray, np.ndarray]: 
    """cvの分割方法に従って予測値を算出する."""
    y_train_ = np.array([])
    y_val = np.array([])
    for i, (train_idx, val_idx) in enumerate(cv.split(X_train, y_train)):
        print(f"CV{i}回目")
        # REVIEW: fitが複数回呼ばれた際に，HP等は保持されたままか分からない
        model.fit(X_train[train_idx], y_train[train_idx])
        y_val = np.concatenate([y_val, model.predict(X_train[val_idx])])
        y_train_ = np.concatenate([y_train_, y_train[val_idx]])
    return y_train_, y_val

# %% [markdown]
# # 分析

# %% [markdown]
# ## データ読み込み

# %%
train_data = pd.read_parquet(Path(DATA_PATH, "train.parquet"))
test_data = pd.read_parquet(Path(DATA_PATH, "test.parquet"))

# %% [markdown]
# ## モデルの学習

# %%
# データ分割
# TODO: 時系列データであることを考慮すべき？
feature_cols = train_data.drop(columns=["id", "target"]).columns
target_col = "target"
X_train, X_valid, y_train, y_valid = train_test_split(
    train_data[feature_cols], 
    train_data[target_col], 
    test_size=0.3
)

print(f'X_trainのshape:{X_train.shape}')
print(f'y_trainのshape:{y_train.shape}')
print(f'X_validのshape:{X_valid.shape}')
print(f'y_validのshape:{y_valid.shape}')
# Out:
# X_trainのshape:(462000, 695)
# y_trainのshape:(462000,)
# X_validのshape:(198000, 695)
# y_validのshape:(198000,)

# %%
# 特徴量選択
selector = SelectKBest(score_func=f_regression, k=100) 
selector.fit(X_train, y_train)
X_train = selector.transform(X_train)
X_valid = selector.transform(X_valid)

print(f'X_trainのshape:{X_train.shape}')
print(f'X_validのshape:{X_valid.shape}')
# Out:
# X_trainのshape:(462000, 100)
# X_validのshape:(198000, 100)

# %%
# パラメータの準備
params = {
    'boosting_type':'gbdt',
    'objective':'regression',
    'metric': 'rmse',
    'num_leaves':16,
    'learning_rate':0.1,
    'n_estimators':100000,
    'random_state':0
}

# %%
# %%time
# モデルの設定
model = lgb.LGBMRegressor(**params)

# モデルの学習
model.fit(
    X_train, 
    y_train,
    eval_set=[(X_train, y_train),(X_valid, y_valid)],
    early_stopping_rounds=10
)
# Out:
# /Users/ryusuke/anaconda3/envs/work/lib/python3.9/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# [827]	training's rmse: 0.958429	valid_1's rmse: 0.983939
# [828]	training's rmse: 0.958396	valid_1's rmse: 0.983922
# [829]	training's rmse: 0.958355	valid_1's rmse: 0.983908
# [830]	training's rmse: 0.958322	valid_1's rmse: 0.983898
# [831]	training's rmse: 0.958288	valid_1's rmse: 0.983884
# [832]	training's rmse: 0.958249	valid_1's rmse: 0.98388
# [833]	training's rmse: 0.958199	valid_1's rmse: 0.983864
# [834]	training's rmse: 0.958145	valid_1's rmse: 0.983834
# [835]	training's rmse: 0.958111	valid_1's rmse: 0.983819
# [836]	training's rmse: 0.958083	valid_1's rmse: 0.983809
# [837]	training's rmse: 0.958039	valid_1's rmse: 0.983787
# [838]	training's rmse: 0.958013	valid_1's rmse: 0.98378
# [839]	training's rmse: 0.957967	valid_1's rmse: 0.983751
# [840]	training's rmse: 0.957927	valid_1's rmse: 0.983728
# ...
# [2650]	training's rmse: 0.898435	valid_1's rmse: 0.966231
# [2651]	training's rmse: 0.898396	valid_1's rmse: 0.96622
# [2652]	training's rmse: 0.898362	valid_1's rmse: 0.966211
# [2653]	training's rmse: 0.898353	valid_1's rmse: 0.966206
# [2654]	training's rmse: 0.898326	valid_1's rmse: 0.9662
# [2655]	training's rmse: 0.898296	valid_1's rmse: 0.966183
# [2656]	training's rmse: 0.898274	valid_1's rmse: 0.966177
# [2657]	training's rmse: 0.89825	valid_1's rmse: 0.966172
# [2658]	training's rmse: 0.898219	valid_1's rmse: 0.966169
# [2659]	training's rmse: 0.898196	valid_1's rmse: 0.966167
# [2660]	training's rmse: 0.898167	valid_1's rmse: 0.966163
# [2661]	training's rmse: 0.898152	valid_1's rmse: 0.966163
# [2662]	training's rmse: 0.898126	valid_1's rmse: 0.966151
# [2663]	training's rmse: 0.898084	valid_1's rmse: 0.966133
# [2664]	training's rmse: 0.898066	valid_1's rmse: 0.966133
# [2665]	training's rmse: 0.898039	valid_1's rmse: 0.966125
# [2666]	training's rmse: 0.898008	valid_1's rmse: 0.96612
# [2667]	training's rmse: 0.897991	valid_1's rmse: 0.96611
# [2668]	training's rmse: 0.89796	valid_1's rmse: 0.966099
# [2669]	training's rmse: 0.897926	valid_1's rmse: 0.966093
# [2670]	training's rmse: 0.897883	valid_1's rmse: 0.966086
# [2671]	training's rmse: 0.897859	valid_1's rmse: 0.966083
# [2672]	training's rmse: 0.89783	valid_1's rmse: 0.966069
# [2673]	training's rmse: 0.897806	valid_1's rmse: 0.966066
# [2674]	training's rmse: 0.897782	valid_1's rmse: 0.96606
# [2675]	training's rmse: 0.897761	valid_1's rmse: 0.966053
# [2676]	training's rmse: 0.897743	valid_1's rmse: 0.966046
# [2677]	training's rmse: 0.897705	valid_1's rmse: 0.966035
# [2678]	training's rmse: 0.897683	valid_1's rmse: 0.966026
# [2679]	training's rmse: 0.897666	valid_1's rmse: 0.966018
# [2680]	training's rmse: 0.897642	valid_1's rmse: 0.966018
# [2681]	training's rmse: 0.897603	valid_1's rmse: 0.966
# [2682]	training's rmse: 0.897582	valid_1's rmse: 0.965998
# [2683]	training's rmse: 0.897554	valid_1's rmse: 0.965998
# [2684]	training's rmse: 0.897524	valid_1's rmse: 0.965984
# [2685]	training's rmse: 0.897502	valid_1's rmse: 0.965979
# [2686]	training's rmse: 0.897474	valid_1's rmse: 0.965975
# [2687]	training's rmse: 0.897442	valid_1's rmse: 0.965974
# [2688]	training's rmse: 0.89741	valid_1's rmse: 0.965965
# [2689]	training's rmse: 0.897383	valid_1's rmse: 0.965951
# [2690]	training's rmse: 0.897356	valid_1's rmse: 0.965939
# [2691]	training's rmse: 0.897317	valid_1's rmse: 0.96593
# [2692]	training's rmse: 0.897287	valid_1's rmse: 0.965929
# [2693]	training's rmse: 0.897254	valid_1's rmse: 0.965923
# [2694]	training's rmse: 0.897224	valid_1's rmse: 0.965918
# [2695]	training's rmse: 0.897179	valid_1's rmse: 0.965886
# [2696]	training's rmse: 0.897156	valid_1's rmse: 0.965879
# [2697]	training's rmse: 0.897125	valid_1's rmse: 0.965879
# [2698]	training's rmse: 0.897098	valid_1's rmse: 0.965875
# [2699]	training's rmse: 0.897076	valid_1's rmse: 0.96587
# [2700]	training's rmse: 0.897043	valid_1's rmse: 0.965857
# [2701]	training's rmse: 0.897024	valid_1's rmse: 0.965851
# [2702]	training's rmse: 0.896989	valid_1's rmse: 0.965844
# [2703]	training's rmse: 0.89696	valid_1's rmse: 0.96583
# [2704]	training's rmse: 0.896942	valid_1's rmse: 0.965826
# [2705]	training's rmse: 0.896904	valid_1's rmse: 0.965806
# [2706]	training's rmse: 0.896871	valid_1's rmse: 0.965798
# [2707]	training's rmse: 0.896845	valid_1's rmse: 0.965782
# [2708]	training's rmse: 0.896807	valid_1's rmse: 0.965776
# [2709]	training's rmse: 0.896779	valid_1's rmse: 0.96577
# [2710]	training's rmse: 0.896747	valid_1's rmse: 0.965756
# [2711]	training's rmse: 0.896723	valid_1's rmse: 0.965746
# [2712]	training's rmse: 0.896693	valid_1's rmse: 0.96574
# [2713]	training's rmse: 0.896651	valid_1's rmse: 0.965726
# [2714]	training's rmse: 0.896606	valid_1's rmse: 0.965717
# [2715]	training's rmse: 0.896587	valid_1's rmse: 0.965704
# [2716]	training's rmse: 0.896565	valid_1's rmse: 0.965696
# [2717]	training's rmse: 0.896534	valid_1's rmse: 0.965682
# [2718]	training's rmse: 0.896504	valid_1's rmse: 0.96567
# [2719]	training's rmse: 0.896485	valid_1's rmse: 0.965668
# [2720]	training's rmse: 0.896449	valid_1's rmse: 0.965658
# [2721]	training's rmse: 0.896428	valid_1's rmse: 0.965661
# [2722]	training's rmse: 0.896401	valid_1's rmse: 0.965654
# [2723]	training's rmse: 0.896366	valid_1's rmse: 0.965649
# [2724]	training's rmse: 0.896326	valid_1's rmse: 0.96564
# [2725]	training's rmse: 0.896297	valid_1's rmse: 0.965626
# [2726]	training's rmse: 0.896257	valid_1's rmse: 0.965604
# [2727]	training's rmse: 0.896237	valid_1's rmse: 0.965598
# [2728]	training's rmse: 0.896191	valid_1's rmse: 0.965588
# [2729]	training's rmse: 0.896158	valid_1's rmse: 0.965578
# [2730]	training's rmse: 0.89613	valid_1's rmse: 0.965572
# [2731]	training's rmse: 0.896095	valid_1's rmse: 0.965555
# [2732]	training's rmse: 0.896068	valid_1's rmse: 0.965551
# [2733]	training's rmse: 0.89604	valid_1's rmse: 0.96555
# [2734]	training's rmse: 0.896026	valid_1's rmse: 0.965552
# [2735]	training's rmse: 0.896009	valid_1's rmse: 0.965549
# [2736]	training's rmse: 0.895977	valid_1's rmse: 0.965536
# [2737]	training's rmse: 0.895947	valid_1's rmse: 0.965523
# [2738]	training's rmse: 0.895914	valid_1's rmse: 0.96551
# [2739]	training's rmse: 0.895894	valid_1's rmse: 0.965501
# [2740]	training's rmse: 0.895873	valid_1's rmse: 0.965493
# [2741]	training's rmse: 0.895844	valid_1's rmse: 0.965484
# [2742]	training's rmse: 0.895829	valid_1's rmse: 0.965483
# [2743]	training's rmse: 0.895795	valid_1's rmse: 0.965474
# [2744]	training's rmse: 0.895767	valid_1's rmse: 0.96547
# [2745]	training's rmse: 0.895738	valid_1's rmse: 0.965463
# [2746]	training's rmse: 0.895724	valid_1's rmse: 0.965463
# [2747]	training's rmse: 0.895701	valid_1's rmse: 0.965456
# [2748]	training's rmse: 0.895674	valid_1's rmse: 0.965453
# [2749]	training's rmse: 0.89566	valid_1's rmse: 0.965451
# [2750]	training's rmse: 0.895637	valid_1's rmse: 0.965446
# [2751]	training's rmse: 0.895609	valid_1's rmse: 0.965438
# [2752]	training's rmse: 0.89558	valid_1's rmse: 0.965436
# [2753]	training's rmse: 0.895548	valid_1's rmse: 0.965422
# [2754]	training's rmse: 0.895526	valid_1's rmse: 0.965416
# [2755]	training's rmse: 0.89551	valid_1's rmse: 0.965412
# [2756]	training's rmse: 0.895483	valid_1's rmse: 0.965394
# [2757]	training's rmse: 0.895449	valid_1's rmse: 0.965382
# [2758]	training's rmse: 0.895424	valid_1's rmse: 0.965383
# [2759]	training's rmse: 0.895398	valid_1's rmse: 0.965368
# [2760]	training's rmse: 0.895368	valid_1's rmse: 0.965369
# [2761]	training's rmse: 0.895344	valid_1's rmse: 0.965368
# [2762]	training's rmse: 0.895325	valid_1's rmse: 0.965365
# [2763]	training's rmse: 0.895304	valid_1's rmse: 0.965359
# [2764]	training's rmse: 0.895279	valid_1's rmse: 0.965358
# [2765]	training's rmse: 0.895253	valid_1's rmse: 0.965342
# [2766]	training's rmse: 0.895233	valid_1's rmse: 0.965334
# [2767]	training's rmse: 0.895208	valid_1's rmse: 0.965335
# [2768]	training's rmse: 0.895187	valid_1's rmse: 0.965331
# [2769]	training's rmse: 0.895163	valid_1's rmse: 0.965328
# [2770]	training's rmse: 0.895151	valid_1's rmse: 0.965327
# [2771]	training's rmse: 0.895109	valid_1's rmse: 0.965321
# [2772]	training's rmse: 0.895084	valid_1's rmse: 0.965316
# [2773]	training's rmse: 0.895066	valid_1's rmse: 0.965314
# [2774]	training's rmse: 0.895041	valid_1's rmse: 0.965302
# [2775]	training's rmse: 0.895009	valid_1's rmse: 0.965281
# [2776]	training's rmse: 0.894984	valid_1's rmse: 0.965276
# [2777]	training's rmse: 0.894936	valid_1's rmse: 0.965266
# [2778]	training's rmse: 0.894899	valid_1's rmse: 0.965256
# [2779]	training's rmse: 0.894869	valid_1's rmse: 0.965242
# [2780]	training's rmse: 0.894839	valid_1's rmse: 0.965237
# [2781]	training's rmse: 0.894801	valid_1's rmse: 0.965221
# [2782]	training's rmse: 0.894791	valid_1's rmse: 0.965222
# [2783]	training's rmse: 0.894765	valid_1's rmse: 0.965216
# [2784]	training's rmse: 0.894745	valid_1's rmse: 0.965216
# [2785]	training's rmse: 0.894705	valid_1's rmse: 0.965204
# [2786]	training's rmse: 0.894675	valid_1's rmse: 0.965193
# [2787]	training's rmse: 0.894648	valid_1's rmse: 0.965195
# [2788]	training's rmse: 0.894625	valid_1's rmse: 0.965194
# [2789]	training's rmse: 0.894592	valid_1's rmse: 0.96517
# [2790]	training's rmse: 0.894561	valid_1's rmse: 0.965175
# [2791]	training's rmse: 0.894535	valid_1's rmse: 0.965168
# [2792]	training's rmse: 0.89452	valid_1's rmse: 0.965163
# [2793]	training's rmse: 0.894502	valid_1's rmse: 0.965166
# [2794]	training's rmse: 0.894464	valid_1's rmse: 0.965143
# [2795]	training's rmse: 0.894436	valid_1's rmse: 0.965141
# [2796]	training's rmse: 0.8944	valid_1's rmse: 0.965135
# [2797]	training's rmse: 0.894378	valid_1's rmse: 0.965128
# [2798]	training's rmse: 0.894342	valid_1's rmse: 0.96512
# [2799]	training's rmse: 0.894314	valid_1's rmse: 0.965116
# [2800]	training's rmse: 0.894285	valid_1's rmse: 0.965111
# [2801]	training's rmse: 0.894264	valid_1's rmse: 0.965108
# [2802]	training's rmse: 0.894235	valid_1's rmse: 0.965107
# [2803]	training's rmse: 0.894209	valid_1's rmse: 0.965098
# [2804]	training's rmse: 0.894179	valid_1's rmse: 0.965089
# [2805]	training's rmse: 0.894145	valid_1's rmse: 0.965087
# [2806]	training's rmse: 0.894122	valid_1's rmse: 0.965071
# [2807]	training's rmse: 0.894103	valid_1's rmse: 0.965059
# [2808]	training's rmse: 0.894077	valid_1's rmse: 0.965057
# [2809]	training's rmse: 0.894046	valid_1's rmse: 0.965051
# [2810]	training's rmse: 0.894018	valid_1's rmse: 0.965041
# [2811]	training's rmse: 0.893992	valid_1's rmse: 0.965039
# [2812]	training's rmse: 0.893965	valid_1's rmse: 0.965029
# [2813]	training's rmse: 0.89395	valid_1's rmse: 0.965034
# [2814]	training's rmse: 0.893911	valid_1's rmse: 0.965025
# [2815]	training's rmse: 0.893885	valid_1's rmse: 0.965017
# [2816]	training's rmse: 0.893866	valid_1's rmse: 0.965012
# [2817]	training's rmse: 0.893848	valid_1's rmse: 0.965007
# [2818]	training's rmse: 0.893827	valid_1's rmse: 0.965003
# [2819]	training's rmse: 0.893797	valid_1's rmse: 0.96499
# [2820]	training's rmse: 0.893774	valid_1's rmse: 0.964994
# [2821]	training's rmse: 0.893751	valid_1's rmse: 0.964993
# [2822]	training's rmse: 0.893711	valid_1's rmse: 0.964987
# [2823]	training's rmse: 0.893684	valid_1's rmse: 0.964986
# [2824]	training's rmse: 0.893667	valid_1's rmse: 0.964983
# [2825]	training's rmse: 0.893643	valid_1's rmse: 0.964973
# [2826]	training's rmse: 0.893614	valid_1's rmse: 0.964959
# [2827]	training's rmse: 0.893583	valid_1's rmse: 0.964939
# [2828]	training's rmse: 0.893564	valid_1's rmse: 0.964941
# [2829]	training's rmse: 0.893536	valid_1's rmse: 0.96493
# [2830]	training's rmse: 0.893501	valid_1's rmse: 0.964923
# [2831]	training's rmse: 0.893469	valid_1's rmse: 0.964916
# [2832]	training's rmse: 0.893445	valid_1's rmse: 0.964917
# [2833]	training's rmse: 0.893414	valid_1's rmse: 0.964906
# [2834]	training's rmse: 0.893379	valid_1's rmse: 0.964893
# [2835]	training's rmse: 0.893347	valid_1's rmse: 0.964889
# [2836]	training's rmse: 0.893314	valid_1's rmse: 0.964878
# [2837]	training's rmse: 0.893297	valid_1's rmse: 0.964873
# [2838]	training's rmse: 0.893265	valid_1's rmse: 0.964869
# [2839]	training's rmse: 0.893235	valid_1's rmse: 0.964865
# [2840]	training's rmse: 0.893204	valid_1's rmse: 0.964863
# [2841]	training's rmse: 0.893174	valid_1's rmse: 0.964853
# [2842]	training's rmse: 0.893144	valid_1's rmse: 0.964851
# [2843]	training's rmse: 0.893118	valid_1's rmse: 0.964844
# [2844]	training's rmse: 0.893096	valid_1's rmse: 0.964839
# [2845]	training's rmse: 0.893067	valid_1's rmse: 0.964838
# [2846]	training's rmse: 0.893038	valid_1's rmse: 0.964821
# [2847]	training's rmse: 0.893016	valid_1's rmse: 0.964818
# [2848]	training's rmse: 0.892992	valid_1's rmse: 0.964813
# [2849]	training's rmse: 0.892967	valid_1's rmse: 0.964799
# [2850]	training's rmse: 0.892942	valid_1's rmse: 0.964791
# [2851]	training's rmse: 0.892915	valid_1's rmse: 0.964791
# [2852]	training's rmse: 0.892886	valid_1's rmse: 0.964785
# [2853]	training's rmse: 0.892853	valid_1's rmse: 0.964771
# [2854]	training's rmse: 0.892831	valid_1's rmse: 0.964767
# [2855]	training's rmse: 0.892805	valid_1's rmse: 0.964756
# [2856]	training's rmse: 0.892775	valid_1's rmse: 0.964742
# [2857]	training's rmse: 0.892726	valid_1's rmse: 0.96473
# [2858]	training's rmse: 0.892689	valid_1's rmse: 0.964716
# [2859]	training's rmse: 0.892661	valid_1's rmse: 0.964713
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:5
#
# File ~/anaconda3/envs/work/lib/python3.9/site-packages/lightgbm/sklearn.py:895, in LGBMRegressor.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     888 def fit(self, X, y,
#     889         sample_weight=None, init_score=None,
#     890         eval_set=None, eval_names=None, eval_sample_weight=None,
#     891         eval_init_score=None, eval_metric=None, early_stopping_rounds=None,
#     892         verbose='warn', feature_name='auto', categorical_feature='auto',
#     893         callbacks=None, init_model=None):
#     894     """Docstring is inherited from the LGBMModel."""
# --> 895     super().fit(X, y, sample_weight=sample_weight, init_score=init_score,
#     896                 eval_set=eval_set, eval_names=eval_names, eval_sample_weight=eval_sample_weight,
#     897                 eval_init_score=eval_init_score, eval_metric=eval_metric,
#     898                 early_stopping_rounds=early_stopping_rounds, verbose=verbose, feature_name=feature_name,
#     899                 categorical_feature=categorical_feature, callbacks=callbacks, init_model=init_model)
#     900     return self
#
# File ~/anaconda3/envs/work/lib/python3.9/site-packages/lightgbm/sklearn.py:748, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     745 evals_result = {}
#     746 callbacks.append(record_evaluation(evals_result))
# --> 748 self._Booster = train(
#     749     params=params,
#     750     train_set=train_set,
#     751     num_boost_round=self.n_estimators,
#     752     valid_sets=valid_sets,
#     753     valid_names=eval_names,
#     754     fobj=self._fobj,
#     755     feval=eval_metrics_callable,
#     756     init_model=init_model,
#     757     feature_name=feature_name,
#     758     callbacks=callbacks
#     759 )
#     761 if evals_result:
#     762     self._evals_result = evals_result
#
# File ~/anaconda3/envs/work/lib/python3.9/site-packages/lightgbm/engine.py:298, in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     296 if valid_sets is not None:
#     297     if is_valid_contain_train:
# --> 298         evaluation_result_list.extend(booster.eval_train(feval))
#     299     evaluation_result_list.extend(booster.eval_valid(feval))
#     300 try:
#
# File ~/anaconda3/envs/work/lib/python3.9/site-packages/lightgbm/basic.py:3238, in Booster.eval_train(self, feval)
#    3207 def eval_train(self, feval=None):
#    3208     """Evaluate for training data.
#    3209
#    3210     Parameters
#    (...)
#    3236         List with evaluation results.
#    3237     """
# -> 3238     return self.__inner_eval(self._train_data_name, 0, feval)
#
# File ~/anaconda3/envs/work/lib/python3.9/site-packages/lightgbm/basic.py:3789, in Booster.__inner_eval(self, data_name, data_idx, feval)
#    3787 result = np.empty(self.__num_inner_eval, dtype=np.float64)
#    3788 tmp_out_len = ctypes.c_int(0)
# -> 3789 _safe_call(_LIB.LGBM_BoosterGetEval(
#    3790     self.handle,
#    3791     ctypes.c_int(data_idx),
#    3792     ctypes.byref(tmp_out_len),
#    3793     result.ctypes.data_as(ctypes.POINTER(ctypes.c_double))))
#    3794 if tmp_out_len.value != self.__num_inner_eval:
#    3795     raise ValueError("Wrong length of eval results")
#
# KeyboardInterrupt:

# %%
# 精度
y_train_pred = model.predict(X_train)
y_valid_pred = model.predict(X_valid)
print(f"trainの精度：{cosine_similarity(y_train, y_train_pred)}")
print(f"validの精度：{cosine_similarity(y_valid, y_valid_pred)}")
# Out:
# trainの精度：0.30204719310715356
# validの精度：0.10335585223513896

# %% [markdown]
# ## テストデータの予測

# %%
# 予測
id_test = test_data["id"].values.reshape(-1)
X_test = test_data.drop(columns=["id"]).copy()
X_test_selected = selector.transform(X_test)

# %%
y_test_pred = model.predict(X_test_selected)

# %%
# 保存
result = pd.DataFrame(data=y_test_pred, index=id_test, columns=["target"]).reset_index().rename(columns={"index": "id"})
result.to_csv(Path(RESULT_PATH, "20230820_LGBM_feature_selection.csv"), index=False)

# %% [markdown]
# # 参考サイト
# - https://qiita.com/rockhopper/items/a68ceb3248f2b3a41c89
